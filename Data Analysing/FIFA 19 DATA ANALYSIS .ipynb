# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fifa_df = pd.read_csv('./fifa19.csv')

# %%
fifa_df.head(20)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
# 15          15  211110          P. Dybala   24
# 16          16  202126            H. Kane   24
# 17          17  194765       A. Griezmann   27
# 18          18  192448      M. ter Stegen   26
# ...

# %%
fifa_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
fifa_df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
fifa_df.shape
# Out:
# (18207, 88)

# %%
fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# Skill Moves                 18159 non-null float64
# ...

# %%
fifa_df.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# ...

# %%
pd.set_option('display.max.columns', 88)

# %%
fifa_df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %% [markdown]
# ###  Players Rating

# %%
fifa_df.Overall.isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(12, 8))
fifa_df.Overall.value_counts().sort_index().plot(kind='bar')

# %%
fifa_df.Overall.value_counts().sort_index().plot()

# %% [markdown]
# #### Why Majority Players are rated 63 - 68 ?

# %%
less_rated = fifa_df[(fifa_df['Overall'] >= 63) & (fifa_df['Overall'] <= 68)]

# %%
less_rated.shape
# Out:
# (6454, 88)

# %%
less_rated.head(10)
# Out:
#           ID               Name  Age  \
# 6611  197376        C. Fandrich   27
# 6612  212224           G. Bueno   24
# 6613  189952         K. Çelikay   30
# 6614  223746         G. Stewart   28
# 6615  226050        C. Teuchert   21
# 6616  164610     J. Larentowicz   34
# 6617  193794         Villalibre   20
# 6618  194050            M. Grün   31
# 6619  198147  M. van der Maarel   28
# 6620  212483          J. Obiang   24
#
#                                                Photo    Nationality  \
# 6611  https://cdn.sofifa.org/players/4/19/197376.png        Germany
# 6612  https://cdn.sofifa.org/players/4/19/212224.png        Uruguay
# 6613  https://cdn.sofifa.org/players/4/19/189952.png         Turkey
# 6614  https://cdn.sofifa.org/players/4/19/223746.png       Scotland
# 6615  https://cdn.sofifa.org/players/4/19/226050.png        Germany
# 6616  https://cdn.sofifa.org/players/4/19/164610.png  United States
# 6617  https://cdn.sofifa.org/players/4/19/193794.png          Spain
# ...

# %% [markdown]
# # From where they belong

# %%
fifa_df.Nationality.isnull().sum()
# Out:
# 0

# %%
less_rated.groupby('Nationality').size()
# Out:
# Nationality
# Afghanistan               1
# Albania                  17
# Algeria                  16
# Angola                    5
# Antigua & Barbuda         1
# Argentina               271
# Armenia                   6
# Australia                96
# Austria                 131
# Azerbaijan                3
# Barbados                  2
# Belarus                   1
# Belgium                  96
# Benin                     8
# Bermuda                   1
# Bolivia                  21
# Bosnia Herzegovina       18
# Brazil                  222
# Bulgaria                 14
# Burkina Faso              9
# Burundi                   1
# Cameroon                 31
# Canada                   26
# Cape Verde                5
# Central African Rep.      1
# Chad                      1
# Chile                   162
# China PR                116
# Colombia                244
# Comoros                   2
#                        ...
# Rwanda                    1
# ...

# %% [markdown]
# ### TOP 10 less rated players by country

# %%
plt.figure(dpi=100)
less_rated.groupby('Nationality').size().sort_values(ascending=False).head(10).plot(kind='pie', autopct='%1.1f%%', explode=np.arange(10)*0.02)
plt.title('Less rated Players by Countries', pad=14)
plt.ylabel('')
plt.legend(title='Countries', loc='upper right', bbox_to_anchor=(0.10, 0.10))

# %%
less_rated.groupby('Age').size().plot()

# %% [markdown]
# #### Why Some Players that are aged are lying between 63 - 68

# %%
less_rated.Club[less_rated.Age >= 35].value_counts().head().plot(kind='pie', autopct='%1.1f%%')

# %%
less_rated.Club[((less_rated.Age >= 20) & (less_rated.Age <= 25))].value_counts().sort_values()
# Out:
# Cheltenham Town            1
# Manchester United          1
# Wellington Phoenix         1
# Millwall                   1
# Brighton & Hove Albion     1
# Sarpsborg 08 FF            1
# Grimsby Town               1
# Yeni Malatyaspor           1
# Al Batin                   1
# Śląsk Wrocław              1
# Hamilton Academical FC     1
# SD Huesca                  1
# Southampton                1
# Deportivo Alavés           1
# SL Benfica                 1
# Galatasaray SK             1
# St. Patrick's Athletic     1
# Kayserispor                1
# Cardiff City               1
# Al Faisaly                 1
# VfL Wolfsburg              1
# FC København               1
# AS Saint-Étienne           1
# Bologna                    1
# Beijing Renhe FC           1
# Sanfrecce Hiroshima        1
# Medipol Başakşehir FK      1
# Tigres U.A.N.L.            1
# TSG 1899 Hoffenheim        1
# PSV                        1
#                           ..
# SC Paderborn 07           10
# ...

# %% [markdown]
# #### Any Player From Barcelona, Real Madrid, PSG, Liverpool, Manchester City And United, Bayern Munich that are less rated?

# %%
top_club_but_less_rated_players = less_rated[(less_rated.Club == 'FC Barcelona') | (less_rated.Club == 'Real Madrid') | (less_rated.Club == 'Liverpool') | (less_rated.Club == 'Paris Saint-Germain') | (less_rated.Club == 'Manchester City') | (less_rated.Club == 'Manchester United') | (less_rated.Club == 'FC Bayern München')]

# %%
top_club_but_less_rated_players
# Out:
#            ID              Name  Age  \
# 6690   241941          S. Nsoki   19
# 6724   245279          Reguilón   21
# 8191   240507          A. Gomes   17
# 8284   239249    Oriol Busquets   19
# 8289   239250         Abel Ruiz   18
# 8732   245238      Javi Sánchez   21
# 8853   224019  Pedro Chirivella   21
# 8857   240915           Miranda   18
# 8966   245035          C. Gomes   17
# 9141   225105   Cristo González   20
# 9935   235266        C. Früchtl   18
# 10087  233510          T. Chong   18
# 10178  241467   F. Feuillassier   20
# 10269  246608           Fidalgo   21
# 10457  240513       E. Hamilton   19
# 10461  237698        C. Gribbin   19
# 10526  241810             Chumi   19
# 10620  243627           Y. Adli   17
# 10777  237522      Jorge Cuenca   18
# 11081  225557          R. Poole   20
# 11163  245287      Sergio López   19
# 11179  234795        A. Bernede   19
# 11300  246599     Guillem Jaime   19
# 11319  243275            L. Mai   18
# ...

# %%
top_club_but_less_rated_players.shape
# Out:
# (35, 88)

# %%
top_club_but_less_rated_players.Age.hist()
plt.title('Top Club Less Rated Players Age', pad=20, size=18)
plt.xlabel('Age', labelpad=20, size=14)
plt.ylabel('Frequency', labelpad=20, size=14)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
top_club_but_less_rated_players.Age.value_counts()
# Out:
# 19    14
# 18     7
# 21     5
# 17     5
# 20     3
# 27     1
# Name: Age, dtype: int64

# %% [markdown]
# #### Top Club Less Rated With 80+ Potential

# %%
plt.figure(dpi=100)
top_club_but_less_rated_players.Club[top_club_but_less_rated_players.Potential >= 80].value_counts().sort_index().plot(kind='barh', color='magenta')
plt.title('No of Players from top teams with 80+ potential', pad=20, size=14)
# Out:
# Text(0.5, 1.0, 'No of Players from top teams with 80+ potential')

# %%
plt.figure(dpi=100)
top_club_but_less_rated_players.Nationality.value_counts().plot(kind='pie', startangle=90, autopct='%1.1f%%', explode=[0.01, 0.01, 0.01, 0.01, 0.19, 0.29, 0.39, 0.49])
plt.title('Nationality % of (Top Club Less Rated Players) with 80+ Potential', pad=50)
plt.ylabel('Nationality', labelpad=40)
plt.legend(title='Nationality', loc='upper right', bbox_to_anchor=(0.10, 0.10))

# %%
top_club_but_less_rated_players.Age[top_club_but_less_rated_players.Potential >= 80].value_counts().sort_index().plot(linewidth=4, title='80+ Potential Players Age')

# %% [markdown]
# ### Their Value ?

# %%
_80Plus = top_club_but_less_rated_players[top_club_but_less_rated_players.Potential >= 80]

# %%
_80Plus
# Out:
#            ID              Name  Age  \
# 6690   241941          S. Nsoki   19
# 6724   245279          Reguilón   21
# 8191   240507          A. Gomes   17
# 8284   239249    Oriol Busquets   19
# 8289   239250         Abel Ruiz   18
# 8857   240915           Miranda   18
# 8966   245035          C. Gomes   17
# 9935   235266        C. Früchtl   18
# 10087  233510          T. Chong   18
# 10178  241467   F. Feuillassier   20
# 10461  237698        C. Gribbin   19
# 10526  241810             Chumi   19
# 10620  243627           Y. Adli   17
# 11163  245287      Sergio López   19
# 11300  246599     Guillem Jaime   19
# 11319  243275            L. Mai   18
# 12290  244024  O. Batista Meier   17
# 12357  229194        A. Georgen   19
# 12679  243357          F. Evina   17
#
#                                                 Photo  Nationality  \
# 6690   https://cdn.sofifa.org/players/4/19/241941.png       France
# 6724   https://cdn.sofifa.org/players/4/19/245279.png        Spain
# ...

# %% [raw]
# string = '€1.1M'
# float(string.split('€')[1].split('M')[0]) * 1_000_000

# %%
def split_and_convert(row):
    if 'M' in row:
        return float(row.split('€')[1].split('M')[0]) * 1_000_000
    else:
        return float(row.split('€')[1].split('K')[0]) * 1_000

# %% [markdown]
# a = lambda x: if 'M' in x: float(x.split('€')[1].split('M')[0])*1_000_000

# %%
_80_rated_players_value = _80Plus['Value'].apply(split_and_convert)

# %%
_80_rated_players_value.index = range(len(_80_rated_players_value))

# %%
_80_rated_players_value
# Out:
# 0     1700000.0
# 1     1400000.0
# 2     1500000.0
# 3     1500000.0
# 4     1600000.0
# 5     1200000.0
# 6     1100000.0
# 7     1000000.0
# 8     1100000.0
# 9     1200000.0
# 10    1200000.0
# 11    1000000.0
# 12    1100000.0
# 13     875000.0
# 14     975000.0
# 15     850000.0
# 16     725000.0
# 17     700000.0
# 18     725000.0
# Name: Value, dtype: float64

# %%
_80_rated_players_value.plot()
