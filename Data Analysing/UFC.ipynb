# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ufc = pd.read_csv('./raw_total_fight_data.csv', sep=';')

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... B_GROUND  \
# 0           52%           47%    99 of 182    59 of 121  ...   1 of 1
# 1           72%           16%     37 of 40     42 of 52  ...   0 of 0
# 2           52%           36%   104 of 200    68 of 185  ...   0 of 0
# 3           38%           29%    76 of 195    58 of 192  ...  4 of 10
# 4           44%           59%    66 of 146    81 of 131  ...   6 of 6
#
#                     win_by last_round last_round_time             Format  \
# ...

# %%
ufc.dtypes
# Out:
# R_fighter          object
# B_fighter          object
# R_KD                int64
# B_KD                int64
# R_SIG_STR.         object
# B_SIG_STR.         object
# R_SIG_STR_pct      object
# B_SIG_STR_pct      object
# R_TOTAL_STR.       object
# B_TOTAL_STR.       object
# R_TD               object
# B_TD               object
# R_TD_pct           object
# B_TD_pct           object
# R_SUB_ATT           int64
# B_SUB_ATT           int64
# R_PASS              int64
# B_PASS              int64
# R_REV               int64
# B_REV               int64
# R_HEAD             object
# B_HEAD             object
# R_BODY             object
# B_BODY             object
# R_LEG              object
# B_LEG              object
# R_DISTANCE         object
# B_DISTANCE         object
# R_CLINCH           object
# B_CLINCH           object
# R_GROUND           object
# B_GROUND           object
# win_by             object
# last_round          int64
# last_round_time    object
# ...

# %%
ufc.describe()
# Out:
#               R_KD         B_KD    R_SUB_ATT    B_SUB_ATT       R_PASS  \
# count  5144.000000  5144.000000  5144.000000  5144.000000  5144.000000
# mean      0.252333     0.180404     0.510886     0.361003     1.401439
# std       0.523318     0.459646     0.948139     0.809795     2.301587
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     0.000000     2.000000
# max       5.000000     4.000000    10.000000     7.000000    26.000000
#
#             B_PASS        R_REV        B_REV   last_round
# count  5144.000000  5144.000000  5144.000000  5144.000000
# mean      0.831260     0.141719     0.134137     2.288297
# std       1.651515     0.427448     0.416798     1.003732
# min       0.000000     0.000000     0.000000     1.000000
# ...

# %%
ufc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5144 entries, 0 to 5143
# Data columns (total 41 columns):
# R_fighter          5144 non-null object
# B_fighter          5144 non-null object
# R_KD               5144 non-null int64
# B_KD               5144 non-null int64
# R_SIG_STR.         5144 non-null object
# B_SIG_STR.         5144 non-null object
# R_SIG_STR_pct      5144 non-null object
# B_SIG_STR_pct      5144 non-null object
# R_TOTAL_STR.       5144 non-null object
# B_TOTAL_STR.       5144 non-null object
# R_TD               5144 non-null object
# B_TD               5144 non-null object
# R_TD_pct           5144 non-null object
# B_TD_pct           5144 non-null object
# R_SUB_ATT          5144 non-null int64
# B_SUB_ATT          5144 non-null int64
# R_PASS             5144 non-null int64
# B_PASS             5144 non-null int64
# R_REV              5144 non-null int64
# B_REV              5144 non-null int64
# R_HEAD             5144 non-null object
# ...

# %%
len(ufc.columns)
# Out:
# 41

# %%
ufc.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR.', 'B_SIG_STR.',
#        'R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
#        'R_TD', 'B_TD', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_PASS', 'B_PASS', 'R_REV', 'B_REV', 'R_HEAD', 'B_HEAD', 'R_BODY',
#        'B_BODY', 'R_LEG', 'B_LEG', 'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH',
#        'B_CLINCH', 'R_GROUND', 'B_GROUND', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner'],
#       dtype='object')

# %%
ufc['R_SIG_STR.'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Splitting significant strike attempted and landed in separate columns.

# %%
ufc['R_SIG_STR_ATTEMPT'] = ufc['R_SIG_STR.'].apply(lambda x : int(x.split('of')[-1]))

# %%
ufc['R_SIG_STR_LANDED'] = ufc['R_SIG_STR.'].apply(lambda x : int(x.split('of')[0]))

# %%
ufc['B_SIG_STR_ATTEMPT'] = ufc['B_SIG_STR.'].apply(lambda x : int(x.split('of')[-1]))

# %%
ufc['B_SIG_STR_LANDED'] = ufc['B_SIG_STR.'].apply(lambda x : int(x.split('of')[0]))

# %% [markdown]
# # Deleting R_SIG_STR AND B_STG_STR columns

# %%
ufc.drop(['R_SIG_STR.', 'B_SIG_STR.'], axis=1, inplace=True)

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD R_SIG_STR_pct  \
# 0          Henry Cejudo   Marlon Moraes     0     0           52%
# 1  Valentina Shevchenko     Jessica Eye     1     0           72%
# 2         Tony Ferguson  Donald Cerrone     0     0           52%
# 3         Jimmie Rivera        Petr Yan     0     2           38%
# 4           Tai Tuivasa   Blagoy Ivanov     0     1           44%
#
#   B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.    R_TD    B_TD  ...  \
# 0           47%    99 of 182    59 of 121  1 of 4  0 of 2  ...
# 1           16%     37 of 40     42 of 52  2 of 2  0 of 0  ...
# 2           36%   104 of 200    68 of 185  0 of 0  1 of 1  ...
# 3           29%    76 of 195    58 of 192  0 of 3  1 of 3  ...
# 4           59%    66 of 146    81 of 131  0 of 0  2 of 2  ...
#
#               Format          Referee           date                location  \
# 0  5 Rnd (5-5-5-5-5)     Marc Goddard  June 08, 2019  Chicago, Illinois, USA
# ...

# %% [markdown]
# # Same for TOTAL STRIKES BY BLUE AND RED TEAM

# %%
ufc['R_TOTAL_STR_ATTEMPT'] = ufc['R_TOTAL_STR.'].apply(lambda x : int(x.split('of')[-1]))
ufc['R_TOTAL_STR_LANDED'] = ufc['R_TOTAL_STR.'].apply(lambda x : int(x.split('of')[0]))

# %%
ufc['B_TOTAL_STR_ATTEMPT'] = ufc['B_TOTAL_STR.'].apply(lambda x : int(x.split('of')[-1]))
ufc['B_TOTAL_STR_LANDED'] = ufc['B_TOTAL_STR.'].apply(lambda x : int(x.split('of')[0]))

# %%
ufc.drop(['R_TOTAL_STR.', 'B_TOTAL_STR.'], axis=1, inplace=True)

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD R_SIG_STR_pct  \
# 0          Henry Cejudo   Marlon Moraes     0     0           52%
# 1  Valentina Shevchenko     Jessica Eye     1     0           72%
# 2         Tony Ferguson  Donald Cerrone     0     0           52%
# 3         Jimmie Rivera        Petr Yan     0     2           38%
# 4           Tai Tuivasa   Blagoy Ivanov     0     1           44%
#
#   B_SIG_STR_pct    R_TD    B_TD R_TD_pct B_TD_pct  ...  \
# 0           47%  1 of 4  0 of 2      25%       0%  ...
# 1           16%  2 of 2  0 of 0     100%       0%  ...
# 2           36%  0 of 0  1 of 1       0%     100%  ...
# 3           29%  0 of 3  1 of 3       0%      33%  ...
# 4           59%  0 of 0  2 of 2       0%     100%  ...
#
#                          Fight_type                Winner  R_SIG_STR_ATTEMPT  \
# 0       UFC Bantamweight Title Bout          Henry Cejudo                171
# 1  UFC Women's Flyweight Title Bout  Valentina Shevchenko                 11
# ...

# %% [markdown]
# # Converting R_TOTAL_STR. AND B_TOTAL_STR. into float points from %

# %%
ufc['R_SIG_STR_pct'] = ufc['R_SIG_STR_pct'].apply(lambda x : float(x.replace('%', ''))/100)

# %%
ufc['R_SIG_STR_pct'].isnull().sum()
# Out:
# 0

# %%
ufc['B_SIG_STR_pct'] = ufc['B_SIG_STR_pct'].apply(lambda x : float(x.replace('%', ''))/100)

# %%
ufc['B_SIG_STR_pct'].isnull().sum()
# Out:
# 0

# %%
ufc.iloc[0]
# Out:
# R_fighter                             Henry Cejudo
# B_fighter                            Marlon Moraes
# R_KD                                             0
# B_KD                                             0
# R_SIG_STR_pct                                 0.52
# B_SIG_STR_pct                                 0.47
# R_TD                                        1 of 4
# B_TD                                        0 of 2
# R_TD_pct                                       25%
# B_TD_pct                                        0%
# R_SUB_ATT                                        1
# B_SUB_ATT                                        0
# R_PASS                                           1
# B_PASS                                           0
# R_REV                                            0
# B_REV                                            0
# R_HEAD                                   73 of 150
# B_HEAD                                    35 of 89
# ...

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0          Henry Cejudo   Marlon Moraes     0     0           0.52
# 1  Valentina Shevchenko     Jessica Eye     1     0           0.72
# 2         Tony Ferguson  Donald Cerrone     0     0           0.52
# 3         Jimmie Rivera        Petr Yan     0     2           0.38
# 4           Tai Tuivasa   Blagoy Ivanov     0     1           0.44
#
#    B_SIG_STR_pct    R_TD    B_TD R_TD_pct B_TD_pct  ...  \
# 0           0.47  1 of 4  0 of 2      25%       0%  ...
# 1           0.16  2 of 2  0 of 0     100%       0%  ...
# 2           0.36  0 of 0  1 of 1       0%     100%  ...
# 3           0.29  0 of 3  1 of 3       0%      33%  ...
# 4           0.59  0 of 0  2 of 2       0%     100%  ...
#
#                          Fight_type                Winner  R_SIG_STR_ATTEMPT  \
# 0       UFC Bantamweight Title Bout          Henry Cejudo                171
# ...

# %% [markdown]
# # Red team vs Blue team wins

# %%
ufc['Winner'].isnull().sum()  # if Null values
# Out:
# 83

# %%
def red_blue_draw(row):
    
    if row['R_fighter'] == row['Winner']:
        return 'red'
    elif row['B_fighter'] == row['Winner']:
        return 'blue'
    else:
        return 'draw'

# %%
ufc['team'] = ufc[['R_fighter', 'B_fighter', 'Winner']].apply(red_blue_draw, axis=1)

# %%
ufc['team'].isnull().sum()
# Out:
# 0

# %%
ufc.Winner.fillna('draw', inplace=True)

# %%
ufc.Winner.notnull().value_counts()
# Out:
# True    5144
# Name: Winner, dtype: int64

# %%
plt.pie(ufc.team.value_counts(), explode=[0.05,0.05,0.05], autopct="%1.1f%%", labels=['red', 'blue', 'draw'], colors=['orange', 'skyblue', 'cyan'])
# Out:
# ([<matplotlib.patches.Wedge at 0xf7a9bd7e48>,
# ...
#  [Text(-0.5995552670122911, 0.9813426933532549, 'red'),
#   Text(0.5490615427874174, -1.0104609949087107, 'blue'),
#   Text(1.1485228239114695, -0.05826939981176929, 'draw')],
#  [Text(-0.3388790639634689, 0.5546719571127092, '67.5%'),
#   Text(0.3103391328798446, -0.5711301275570972, '30.9%'),
#   Text(0.6491650743847436, -0.03293487815447829, '1.6%')])

# %% [markdown]
# # Checking Strike % of red and blue team

# %%
ufc.R_SIG_STR_pct.hist()

# %%
ufc.B_SIG_STR_pct.hist()

# %%
pd.set_option('display.max.columns', 46)

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0          Henry Cejudo   Marlon Moraes     0     0           0.52
# 1  Valentina Shevchenko     Jessica Eye     1     0           0.72
# 2         Tony Ferguson  Donald Cerrone     0     0           0.52
# 3         Jimmie Rivera        Petr Yan     0     2           0.38
# 4           Tai Tuivasa   Blagoy Ivanov     0     1           0.44
#
#    B_SIG_STR_pct    R_TD    B_TD R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  \
# 0           0.47  1 of 4  0 of 2      25%       0%          1          0
# 1           0.16  2 of 2  0 of 0     100%       0%          1          0
# 2           0.36  0 of 0  1 of 1       0%     100%          0          0
# 3           0.29  0 of 3  1 of 3       0%      33%          0          0
# 4           0.59  0 of 0  2 of 2       0%     100%          0          0
#
#    R_PASS  B_PASS  R_REV  B_REV     R_HEAD     B_HEAD    R_BODY    B_BODY  \
# ...

# %% [markdown]
# # Win By

# %%
# Win types
ufc.groupby(ufc.win_by).size()
# Out:
# win_by
# Could Not Continue           13
# DQ                           15
# Decision - Majority          56
# Decision - Split            486
# Decision - Unanimous       1737
# KO/TKO                     1647
# Other                         2
# Overturned                   35
# Submission                 1083
# TKO - Doctor's Stoppage      70
# dtype: int64

# %%
reds_win_by = ufc.win_by[ufc['team'] == 'red'].value_counts().sort_index()

# %%
blues_win_by = ufc.win_by[ufc['team'] == 'blue'].value_counts().sort_index()

# %%
draws_by = ufc.win_by[ufc['team'] == 'draw'].value_counts().sort_index()

# %%
plt.subplots_adjust(bottom=10, top=20)
fig = plt.figure(dpi=100, figsize=(14, 16))
rect = fig.patch
rect.set_facecolor('silver')
graph1 = fig.add_subplot(3,1,1, fc='black', title='Red Wins By')
graph1.bar(reds_win_by.index, reds_win_by)
graph2 = fig.add_subplot(3,1,2, fc='black', title='Blue Wins By')
graph2.bar(blues_win_by.index, blues_win_by)
graph3 = fig.add_subplot(3,1,3, fc='black', title='Draws By')
graph3.bar(draws_by.index, draws_by)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Conor McGregor insights

# %%
conor_in_red_team = ufc[ufc['R_fighter'] == 'Conor McGregor']

# %%
conor_in_blue_team = ufc[ufc["B_fighter"] == 'Conor McGregor']

# %%
conor_in_red_team
# Out:
#            R_fighter      B_fighter  R_KD  B_KD  R_SIG_STR_pct  B_SIG_STR_pct  \
# 1553  Conor McGregor      Nate Diaz     0     0           0.43           0.50
# 2091  Conor McGregor   Dennis Siver     1     0           0.53           0.30
# 2332  Conor McGregor  Diego Brandao     1     0           0.36           0.40
# 2786  Conor McGregor   Max Holloway     0     0           0.34           0.24
#
#         R_TD    B_TD R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  R_PASS  B_PASS  \
# 1553  0 of 1  1 of 1       0%     100%          0          2       0       1
# 2091  0 of 0  0 of 3       0%       0%          0          0       1       0
# 2332  1 of 1  0 of 2     100%       0%          0          1       1       0
# 2786  4 of 5  0 of 0      80%       0%          0          0       6       0
#
#       R_REV  B_REV     R_HEAD     B_HEAD    R_BODY   B_BODY     R_LEG  \
# 1553      1      0  47 of 117  65 of 131   7 of 11  9 of 13   7 of 12
# ...

# %%
conor_in_blue_team
# Out:
#                 R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 347   Khabib Nurmagomedov  Conor McGregor     0     0           0.58
# 1245        Eddie Alvarez  Conor McGregor     0     3           0.21
# 1348            Nate Diaz  Conor McGregor     0     3           0.48
# 1654            Jose Aldo  Conor McGregor     0     1           0.33
# 1866          Chad Mendes  Conor McGregor     0     1           0.64
# 2240       Dustin Poirier  Conor McGregor     0     1           0.52
# 2919       Marcus Brimage  Conor McGregor     0     1           0.29
#
#       B_SIG_STR_pct    R_TD    B_TD R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  \
# 347            0.62  3 of 7  0 of 0      42%       0%          1          0
# 1245           0.38  0 of 3  0 of 0       0%       0%          0          0
# 1348           0.57  1 of 7  0 of 1      14%       0%          0          0
# 1654           0.83  0 of 0  0 of 0       0%       0%          0          0
# ...

# %%
conor_df = pd.merge(conor_in_red_team, conor_in_blue_team, how='outer')

# %%
conor_df
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0        Conor McGregor       Nate Diaz     0     0           0.43
# 1        Conor McGregor    Dennis Siver     1     0           0.53
# 2        Conor McGregor   Diego Brandao     1     0           0.36
# 3        Conor McGregor    Max Holloway     0     0           0.34
# 4   Khabib Nurmagomedov  Conor McGregor     0     0           0.58
# 5         Eddie Alvarez  Conor McGregor     0     3           0.21
# 6             Nate Diaz  Conor McGregor     0     3           0.48
# 7             Jose Aldo  Conor McGregor     0     1           0.33
# 8           Chad Mendes  Conor McGregor     0     1           0.64
# 9        Dustin Poirier  Conor McGregor     0     1           0.52
# 10       Marcus Brimage  Conor McGregor     0     1           0.29
#
#     B_SIG_STR_pct    R_TD    B_TD R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  \
# 0            0.50  0 of 1  1 of 1       0%     100%          0          2
# ...

# %%
conor_df.team[conor_df['Winner'] == 'Conor McGregor'].value_counts().plot(kind='bar', title='Conor McGregor Wins by team')

# %%
conor_strike_perc_red_win = conor_df['R_SIG_STR_pct'][(conor_df['team'] == 'red') & (conor_df['R_fighter'] == 'Conor McGregor')]

# %%
conor_strike_perc_red_win.mean()
# Out:
# 0.41

# %%
conor_strike_perc_blue_win = conor_df['B_SIG_STR_pct'][(conor_df['team'] == 'blue') & (conor_df['B_fighter'] == 'Conor McGregor')]

# %%
conor_strike_perc_blue_win.mean()
# Out:
# 0.5316666666666666

# %%
plt.pie((conor_strike_perc_red_win.mean(), conor_strike_perc_blue_win.mean()),labels=['Red Team', 'Blue Team'], colors=['magenta', 'violet'], autopct='%1.1f%%', shadow=True, explode=(0.05, 0))
plt.title('Conor Average Strike Percentage as Red and Blue', bbox={'facecolor': '0.8'}, pad=10)
# Out:
# Text(0.5, 1.0, 'Conor Average Strike Percentage as Red and Blue')

# %%
conor_df
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0        Conor McGregor       Nate Diaz     0     0           0.43
# 1        Conor McGregor    Dennis Siver     1     0           0.53
# 2        Conor McGregor   Diego Brandao     1     0           0.36
# 3        Conor McGregor    Max Holloway     0     0           0.34
# 4   Khabib Nurmagomedov  Conor McGregor     0     0           0.58
# 5         Eddie Alvarez  Conor McGregor     0     3           0.21
# 6             Nate Diaz  Conor McGregor     0     3           0.48
# 7             Jose Aldo  Conor McGregor     0     1           0.33
# 8           Chad Mendes  Conor McGregor     0     1           0.64
# 9        Dustin Poirier  Conor McGregor     0     1           0.52
# 10       Marcus Brimage  Conor McGregor     0     1           0.29
#
#     B_SIG_STR_pct    R_TD    B_TD R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  \
# 0            0.50  0 of 1  1 of 1       0%     100%          0          2
# ...

# %% [markdown]
# ## Conor Matches Year

# %%
conor_df.date.dtype
# Out:
# dtype('O')

# %%
conor_df['year'] = pd.to_datetime(conor_df.date)

# %%
conor_df['year'] = conor_df.year.dt.year

# %%
conor_df.year
# Out:
# 0     2016
# 1     2015
# 2     2014
# 3     2013
# 4     2018
# 5     2016
# 6     2016
# 7     2015
# 8     2015
# 9     2014
# 10    2013
# Name: year, dtype: int64

# %%
conor_df.year.value_counts().sort_index().plot(linewidth=3, color='indigo')
plt.title('Conor Matches by Year', pad=14)
# Out:
# Text(0.5, 1.0, 'Conor Matches by Year')

# %%
conor_df
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0        Conor McGregor       Nate Diaz     0     0           0.43
# 1        Conor McGregor    Dennis Siver     1     0           0.53
# 2        Conor McGregor   Diego Brandao     1     0           0.36
# 3        Conor McGregor    Max Holloway     0     0           0.34
# 4   Khabib Nurmagomedov  Conor McGregor     0     0           0.58
# 5         Eddie Alvarez  Conor McGregor     0     3           0.21
# 6             Nate Diaz  Conor McGregor     0     3           0.48
# 7             Jose Aldo  Conor McGregor     0     1           0.33
# 8           Chad Mendes  Conor McGregor     0     1           0.64
# 9        Dustin Poirier  Conor McGregor     0     1           0.52
# 10       Marcus Brimage  Conor McGregor     0     1           0.29
#
#     B_SIG_STR_pct    R_TD    B_TD R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  \
# 0            0.50  0 of 1  1 of 1       0%     100%          0          2
# ...

# %%
fig = plt.figure(dpi=80, figsize=(10, 4))
conor_df.groupby(['Fight_type']).size().plot(kind='barh')
plt.title('No. of Fight Types fought')
# Out:
# Text(0.5, 1.0, 'No. of Fight Types fought')

# %%
plt.figure(dpi=80, figsize=(10, 4))
conor_df['location'].value_counts().sort_index().plot(kind='barh')
plt.title('Conor Matches Location')
# Out:
# Text(0.5, 1.0, 'Conor Matches Location')

# %%
plt.figure(figsize=(10, 4))
conor_df.Referee.value_counts().sort_index().plot(kind='barh')
plt.title('Conor Matches Refree')
# Out:
# Text(0.5, 1.0, 'Conor Matches Refree')

# %% [markdown]
# ###  Conor Matches Win and Lose by Refree

# %%
conor_wins_by_refree = conor_df.Referee[conor_df.Winner == 'Conor McGregor'].value_counts()

# %%
conor_lost_by_refree = conor_df.Referee[~(conor_df.Winner == 'Conor McGregor')].value_counts()

# %%
fig = plt.figure(figsize=(10, 4))
rect = fig.patch
graph = fig.add_subplot(1,1,1, title='Conor\'s No. of Win and Lost matches by Refree {Green: Win | Red: Lost}')
graph.scatter(conor_wins_by_refree.index, conor_wins_by_refree, c='green', s=100)
graph.scatter(conor_lost_by_refree.index, conor_lost_by_refree, c='red', s=100)

# %% [markdown]
# ### Ref in matches

# %%
ufc.Referee.isnull().sum()
# Out:
# 23

# %%
refree_with_total_matches = ufc.Referee.value_counts()
refree_with_total_matches
# Out:
# Herb Dean               726
# John McCarthy           634
# Mario Yamasaki          391
# Dan Miragliotta         347
# Marc Goddard            276
# Yves Lavigne            259
# Steve Mazzagatti        201
# Leon Roberts            179
# Keith Peterson          139
# Josh Rosenthal          119
# Chris Tognoni            89
# Jason Herzog             85
# Steve Perceval           73
# Mark Smith               66
# Jerin Valel              65
# John Sharp               65
# Kevin MacDonald          64
# Kevin Mulhall            59
# Kerry Hatley             45
# Kim Winslow              42
# Neil Hall                40
# Osiris Maia              38
# Larry Landless           38
# Todd Ronald Anderson     36
# Greg Kleynjans           31
# Grant Waterman           31
# Jacob Montalvo           31
# Mike Beltran             28
# Kevin Sataki             27
# Eduardo Herdy            26
#                        ...
# Mark Powell               2
# Al Coley                  2
# ...

# %% [markdown]
# ### TOP 10 Ref by number of matches played

# %%
plt.figure(dpi=128)
refree_with_total_matches.iloc[:10].plot(kind='barh')

# %% [markdown]
# # Khabib insights

# %%
khabib_in_red_team = ufc[ufc.R_fighter == 'Khabib Nurmagomedov']
khabib_in_blue_team = ufc[ufc.B_fighter == 'Khabib Nurmagomedov']
khabib_df = pd.merge(khabib_in_red_team, khabib_in_blue_team, how='outer')

# %%
khabib_df
# Out:
#               R_fighter            B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0   Khabib Nurmagomedov       Conor McGregor     0     0           0.58
# 1   Khabib Nurmagomedov          Al Iaquinta     0     0           0.44
# 2   Khabib Nurmagomedov        Edson Barboza     0     0           0.50
# 3   Khabib Nurmagomedov      Michael Johnson     0     0           0.66
# 4   Khabib Nurmagomedov      Darrell Horcher     0     0           0.71
# 5   Khabib Nurmagomedov        Abel Trujillo     0     0           0.57
# 6      Rafael Dos Anjos  Khabib Nurmagomedov     0     0           0.35
# 7             Pat Healy  Khabib Nurmagomedov     0     0           0.28
# 8        Thiago Tavares  Khabib Nurmagomedov     0     1           0.20
# 9         Gleison Tibau  Khabib Nurmagomedov     0     0           0.32
# 10       Kamal Shalorus  Khabib Nurmagomedov     0     1           0.29
#
#     B_SIG_STR_pct      R_TD     B_TD R_TD_pct B_TD_pct  R_SUB_ATT  B_SUB_ATT  \
# ...

# %%
khabib_df.groupby('Winner').size()
# Out:
# Winner
# Khabib Nurmagomedov    11
# dtype: int64

# %%
fig = plt.figure(figsize=(10, 4))
rect = fig.patch
rect.set_facecolor('white')
graph = fig.add_subplot(1,1,1,fc='white')
graph.set_title('Khabib\'s Fight Significant Strike Percentage as Red and Blue', pad=20, size=16, color='brown')
graph.set_xlabel('No of matches', size=12, labelpad=12, color='brown', style='italic')
graph.set_ylabel('Percentage', size=12, labelpad=12, color='brown', style='italic')
graph.plot(khabib_df.R_SIG_STR_pct[(khabib_df['Winner'] == 'Khabib Nurmagomedov') & (khabib_df.team == 'red')],  linewidth=4, color='red')
graph.plot(khabib_df.R_SIG_STR_pct[(khabib_df['Winner'] == 'Khabib Nurmagomedov') & (khabib_df.team == 'blue')],  linewidth=4)

# %%
plt.figure( figsize=(10, 4))
khabib_df.Fight_type.value_counts().sort_index().plot(kind='bar', title='Khabib\'s Fight types')

# %%
khabib_df.Referee.value_counts().sort_index().plot(kind='bar', title='Khabib fights hosted Ref')

# %%
khabib_df['Year'] = pd.to_datetime(khabib_df.date).dt.year

# %%
khabib_df.Year
# Out:
# 0     2018
# 1     2018
# 2     2017
# 3     2016
# 4     2016
# 5     2013
# 6     2014
# 7     2013
# 8     2013
# 9     2012
# 10    2012
# Name: Year, dtype: int64

# %%
khabib_df.Year.value_counts().sort_index().plot(color='magenta', linewidth=3, title='Khabib Matches Played by Year')

# %% [markdown]
# ## Top 10 Successful Fighters by Win

# %%
plt.figure(dpi=100)
ufc.groupby(['Winner']).size().sort_values(ascending=False)[1:11].plot(kind='bar', color='orange')
plt.xlabel('Winner', labelpad=20)
plt.ylabel('Total Matches', labelpad=20)
# Out:
# Text(0, 0.5, 'Total Matches')

# %% [markdown]
# ## Top 10 unsuccessful fighters by no. of losts
# ### In Blue

# %%
plt.figure(figsize=(10, 4.5))
ufc.B_fighter[(ufc['team'] == 'red')].value_counts().head().plot(linewidth=4, color='brown')

# %% [markdown]
# ### In Red

# %%
plt.figure(figsize=(10, 4.5))
ufc.R_fighter[(ufc['team'] == 'blue')].value_counts().head().plot(linewidth=4, color='red')
